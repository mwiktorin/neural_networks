# %%
import numpy as np
import sympy as sp
sp.init_printing()

# %% [markdown]
# # Assignment2

# %% [markdown]
# 1.13 (a)

# %%
a, b = sp.symbols("a, b")

def phi(x):
    return 1 / (1 + sp.exp(x))

# %%
a1 = a * 5 + b
b1 = -3 * b + 2 * a
a2 = phi(a1)
b2 = phi(b1)
a3 = 3 * a2 - b2
b3 = 6 * b2 + 4 * a2
a4 = phi(a3)
b4 = phi(b3)

# %%
sp.plotting.plot3d(phi(-2 * a4 + b4))
